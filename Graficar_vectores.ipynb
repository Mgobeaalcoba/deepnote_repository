# %% [markdown]
# <a href="https://colab.research.google.com/github/Mgobeaalcoba/Deepnote_Repository/blob/main/Graficar_vectores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Queremos estudiar las combinaciones lineales

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
v1 = np.array([2,5])
v2 = np.array([3,2])

# %%
% run ".\\funciones_auxiliares\graficarVectores.ipynb"
# Out:
# ERROR:root:File `'.\\funciones_auxiliares\\graficarVectores.ipynb.py'` not found.

# %%
graficarVectores([v1,v2],["orange","blue"])
plt.xlim(-1,8)
plt.ylim(-1,8)
# Out:
# (-1.0, 8.0)
